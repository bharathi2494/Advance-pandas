# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Admin\Desktop\Data science\Sunag\Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# # Iterate Row by Row

# %%
for index, row in df.iterrows():
    print(index, row)
# Out:
# 0 price                13300000
# area                     7420
# bedrooms                    4
# bathrooms                   2
# stories                     3
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     2
# prefarea                  yes
# furnishingstatus    furnished
# Name: 0, dtype: object
# 1 price                12250000
# area                     8960
# bedrooms                    4
# bathrooms                   4
# stories                     4
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning           yes
# parking                     3
# prefarea                   no
# furnishingstatus    furnished
# Name: 1, dtype: object
# 2 price                     12250000
# area                          9960
# bedrooms                         3
# ...

# %%
for index, row in df.iterrows():
    print(index, row['basement'])
# Out:
# 0 no
# 1 no
# 2 yes
# 3 yes
# 4 yes
# 5 yes
# 6 no
# 7 no
# 8 yes
# 9 no
# 10 yes
# 11 yes
# 12 no
# 13 no
# 14 no
# 15 yes
# 16 yes
# 17 no
# 18 no
# 19 no
# 20 yes
# 21 yes
# 22 yes
# 23 yes
# 24 no
# 25 yes
# 26 yes
# 27 no
# 28 yes
# 29 yes
# 30 no
# 31 no
# 32 no
# 33 yes
# 34 yes
# 35 no
# 36 no
# 37 no
# 38 no
# 39 no
# 40 yes
# 41 no
# 42 no
# 43 no
# 44 no
# 45 no
# 46 no
# 47 no
# 48 yes
# 49 yes
# 50 no
# 51 no
# 52 no
# 53 no
# 54 no
# 55 no
# 56 yes
# 57 no
# 58 no
# 59 no
# 60 no
# 61 no
# 62 no
# 63 no
# 64 yes
# 65 yes
# 66 yes
# 67 no
# 68 no
# 69 no
# 70 yes
# 71 no
# 72 no
# 73 yes
# 74 yes
# 75 no
# 76 no
# 77 no
# 78 yes
# 79 no
# 80 no
# 81 yes
# 82 yes
# 83 no
# 84 no
# 85 no
# 86 yes
# 87 yes
# 88 yes
# 89 no
# 90 no
# 91 yes
# 92 no
# 93 yes
# 94 no
# 95 no
# 96 yes
# 97 yes
# 98 no
# 99 yes
# 100 yes
# 101 no
# 102 no
# 103 no
# 104 yes
# 105 no
# 106 yes
# 107 yes
# 108 no
# 109 no
# 110 yes
# 111 no
# 112 no
# 113 yes
# 114 yes
# 115 yes
# 116 yes
# ...

# %% [markdown]
# # To change values row by row

# %%
for index, row in df.iterrows():
    if index%2 == 0:
        df.at[index, 'basement']='hi'

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       hi
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no       hi
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes       hi
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no       hi
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       hi
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       hi
#
# ...

# %%
for index, row in df.iterrows():
    df.at[0, 'basement']='Bangalore'

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420         4          2        3      yes        no
# 1    12250000  8960         4          4        4      yes        no
# 2    12250000  9960         3          2        2      yes        no
# 3    12215000  7500         4          2        2      yes        no
# 4    11410000  7420         4          1        2      yes       yes
# ..        ...   ...       ...        ...      ...      ...       ...
# 540   1820000  3000         2          1        1      yes        no
# 541   1767150  2400         3          1        1       no        no
# 542   1750000  3620         2          1        1      yes        no
# 543   1750000  2910         3          1        1       no        no
# 544   1750000  3850         3          1        2      yes        no
#
#       basement hotwaterheating airconditioning  parking prefarea  \
# 0    Bangalore              no             yes        2      yes
# ...

# %% [markdown]
# # convert DF to Dictionary

# %%
dict_file=df.to_dict()
dict_file
# Out:
# {'price': {0: 13300000,
#   1: 12250000,
#   2: 12250000,
#   3: 12215000,
#   4: 11410000,
#   5: 10850000,
#   6: 10150000,
#   7: 10150000,
#   8: 9870000,
#   9: 9800000,
#   10: 9800000,
#   11: 9681000,
#   12: 9310000,
#   13: 9240000,
#   14: 9240000,
#   15: 9100000,
#   16: 9100000,
#   17: 8960000,
#   18: 8890000,
#   19: 8855000,
#   20: 8750000,
#   21: 8680000,
#   22: 8645000,
#   23: 8645000,
#   24: 8575000,
#   25: 8540000,
#   26: 8463000,
#   27: 8400000,
#   28: 8400000,
#   29: 8400000,
#   30: 8400000,
#   31: 8400000,
#   32: 8295000,
#   33: 8190000,
#   34: 8120000,
#   35: 8080940,
#   36: 8043000,
#   37: 7980000,
#   38: 7962500,
#   39: 7910000,
#   40: 7875000,
#   41: 7840000,
#   42: 7700000,
#   43: 7700000,
#   44: 7560000,
#   45: 7560000,
#   46: 7525000,
#   47: 7490000,
#   48: 7455000,
#   49: 7420000,
#   50: 7420000,
#   51: 7420000,
#   52: 7350000,
#   53: 7350000,
#   54: 7350000,
#   55: 7350000,
#   56: 7343000,
#   57: 7245000,
# ...

# %%
DF=pd.DataFrame(dict_file)
DF
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420         4          2        3      yes        no
# 1    12250000  8960         4          4        4      yes        no
# 2    12250000  9960         3          2        2      yes        no
# 3    12215000  7500         4          2        2      yes        no
# 4    11410000  7420         4          1        2      yes       yes
# ..        ...   ...       ...        ...      ...      ...       ...
# 540   1820000  3000         2          1        1      yes        no
# 541   1767150  2400         3          1        1       no        no
# 542   1750000  3620         2          1        1      yes        no
# 543   1750000  2910         3          1        1       no        no
# 544   1750000  3850         3          1        2      yes        no
#
#       basement hotwaterheating airconditioning  parking prefarea  \
# 0    Bangalore              no             yes        2      yes
# ...

# %% [markdown]
# # convert DF to Json Format

# %%
json_file=DF.to_dict(orient='records')
json_file
# Out:
# [{'price': 13300000,
#   'area': 7420,
#   'bedrooms': 4,
#   'bathrooms': 2,
#   'stories': 3,
#   'mainroad': 'yes',
#   'guestroom': 'no',
#   'basement': 'Bangalore',
#   'hotwaterheating': 'no',
#   'airconditioning': 'yes',
#   'parking': 2,
#   'prefarea': 'yes',
#   'furnishingstatus': 'furnished'},
#  {'price': 12250000,
#   'area': 8960,
#   'bedrooms': 4,
#   'bathrooms': 4,
#   'stories': 4,
#   'mainroad': 'yes',
#   'guestroom': 'no',
#   'basement': 'no',
#   'hotwaterheating': 'no',
#   'airconditioning': 'yes',
#   'parking': 3,
#   'prefarea': 'no',
#   'furnishingstatus': 'furnished'},
#  {'price': 12250000,
#   'area': 9960,
#   'bedrooms': 3,
#   'bathrooms': 2,
#   'stories': 2,
#   'mainroad': 'yes',
#   'guestroom': 'no',
#   'basement': 'hi',
#   'hotwaterheating': 'no',
#   'airconditioning': 'no',
#   'parking': 2,
#   'prefarea': 'yes',
#   'furnishingstatus': 'semi-furnished'},
#  {'price': 12215000,
#   'area': 7500,
#   'bedrooms': 4,
# ...

# %% [markdown]
# Json to DF

# %%
final_df=pd.DataFrame(json_file)
final_df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    13300000  7420         4          2        3      yes        no
# 1    12250000  8960         4          4        4      yes        no
# 2    12250000  9960         3          2        2      yes        no
# 3    12215000  7500         4          2        2      yes        no
# 4    11410000  7420         4          1        2      yes       yes
# ..        ...   ...       ...        ...      ...      ...       ...
# 540   1820000  3000         2          1        1      yes        no
# 541   1767150  2400         3          1        1       no        no
# 542   1750000  3620         2          1        1      yes        no
# 543   1750000  2910         3          1        1       no        no
# 544   1750000  3850         3          1        2      yes        no
#
#       basement hotwaterheating airconditioning  parking prefarea  \
# 0    Bangalore              no             yes        2      yes
# ...
